# %%
import numpy as np
import pandas as pd
import time, json, random
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import DBSCAN, KMeans
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import pairwise_distances
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from scipy import stats
import matplotlib.pyplot as plt

RANDOM_STATE = 3

# %%
BORROW_CHECKER_TOKENS = json.load(open("./borrow_checker.json", "r")).keys()
DS = pd.read_csv("./borrow_only.csv", sep=',', header=[0])
X_data = DS.drop(columns=['file', 'scope'])
X_data = X_data.drop_duplicates()
X_data = X_data.drop(columns=['proj', 'commit', 'desc'])
for token in BORROW_CHECKER_TOKENS:
    if(X_data[token].max() != 0):
        X_data[token] = X_data[token] / X_data[token].max()
X_data = X_data[X_data["UseTree"] == 0]
X_data = X_data[X_data["ItemUse"] == 0]
X_data = X_data[X_data["UseGlob"] == 0]
X_data = X_data[X_data["UseList"] == 0]
X_data = X_data[X_data["UsePath"] == 0]
X_data = X_data[X_data["ItemForeignMod"] == 0]
X_data = X_data[X_data["ItemMod"] == 0]
print(len(X_data))
# Out:
# 27143

# %%
dbscan_data = []
Z = [5,7,9]
E = [0.01, 0.001, 0.0001]
for z in Z:
    for e in E:
        db = DBSCAN(eps=e, min_samples=z).fit(X_data)
        core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
        core_samples_mask[db.core_sample_indices_] = True
        labels = db.labels_
        dbscan_labels = pd.Series(labels, name="label")

        n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
        n_noise_ = list(labels).count(-1)

        print("Epsilon", e)
        print("Z", z)
        print("Estimated number of clusters: %d" % n_clusters_)
        print("Estimated number of noise points: %d" % n_noise_)
        dbscan_data.append((z, e, n_clusters_, n_noise_))
print(dbscan_data)
# Out:
# Epsilon 0.01
# Z 5
# Estimated number of clusters: 160
# Estimated number of noise points: 18755
# Epsilon 0.001
# Z 5
# Estimated number of clusters: 102
# Estimated number of noise points: 25909
# Epsilon 0.0001
# Z 5
# Estimated number of clusters: 61
# Estimated number of noise points: 26711
# Epsilon 0.01
# Z 7
# Estimated number of clusters: 77
# Estimated number of noise points: 19324
# Epsilon 0.001
# Z 7
# Estimated number of clusters: 47
# Estimated number of noise points: 26212
# Epsilon 0.0001
# Z 7
# Estimated number of clusters: 23
# Estimated number of noise points: 26910
# Epsilon 0.01
# Z 9
# Estimated number of clusters: 51
# Estimated number of noise points: 19642
# Epsilon 0.001
# Z 9
# Estimated number of clusters: 26
# Estimated number of noise points: 26381
# Epsilon 0.0001
# Z 9
# Estimated number of clusters: 11
# Estimated number of noise points: 27001
# [(5, 0.01, 160, 18755), (5, 0.001, 102, 25909), (5, 0.0001, 61, 26711), (7, 0.01, 77, 19324), (7, 0.001, 47, 26212), (7, 0.0001, 23, 26910), (9, 0.01, 51, 19642), (9, 0.001, 26, 26381), (9, 0.0001, 11, 27001)]

# %%
Z = 5
e = 0.001
db = DBSCAN(eps=e, min_samples=Z).fit(X_data)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
dbscan_labels = pd.Series(labels, name="label")

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Epsilon", e)
print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)
# Out:
# Epsilon 0.001
# Estimated number of clusters: 102
# Estimated number of noise points: 25909

# %%
X_df = pd.DataFrame(data=X_data)
dbscan_labels = pd.Series(labels, name="label", index=X_df.index)
full_dbscan_data = pd.concat([X_df, dbscan_labels], axis = 1)
full_dbscan_clusters = []
for label in range(n_clusters_):
    cluster = full_dbscan_data[full_dbscan_data["label"] == label]
    projects = set()
    for index1, row in cluster.iterrows():
        projects.add(DS.loc[index1, 'proj'])
    if len(projects) > 1:
        full_dbscan_clusters.append(cluster)
print("Clusters with cross-project bugs:",len(full_dbscan_clusters))
# Out:
# Clusters with cross-project bugs: 49

# %%
## Sampling
full_dbscan_clusters.sort(key=len, reverse=True)
DPs = []
for ID in range(1, len(full_dbscan_clusters)):
    samples = full_dbscan_clusters[ID-1]
    projs = set()
    for index1, row in samples.iterrows():
        DPs.append(row)
m = 100
sample = None
for i in range(1000):
    random.seed(RANDOM_STATE+i)
    df = pd.DataFrame(DPs)
    df_sample = pd.DataFrame(random.sample(DPs, k=30))
    sample_error = abs((df.mean(axis = 0) - df_sample.mean(axis = 0)).mean())
    if m > sample_error:
        m = sample_error
        sample = df_sample
print(m)
for index1, row in sample.iterrows():
    print("https://github.com/"+DS.loc[index1, 'proj']+"/commit/"+DS.loc[index1, 'commit']+" "+DS.loc[index1, 'file']+" "+str(DS.loc[index1, 'scope']))
# Out:
# 1.8224230098277807e-05
# https://github.com/tauri-apps/tauri/commit/85674d4fe6a2453ce969d6a75b6528f3c89bf1d1 ios_bundle.rs 1-Fn
# https://github.com/meilisearch/meilisearch/commit/a45cc4b6189c2eb40758b9749c3d1c8b19b88d40 sum_of_words_position.rs 0-Fn
# https://github.com/alacritty/alacritty/commit/5f7885749c4d7e48869b1fc0be4d430601cdbbfa grid.rs 13-Impl
# https://github.com/tokio-rs/tokio/commit/8198ef38814c45f9dc02fcbf826225b5cf32a6bb harness.rs 1-Impl
# https://github.com/starship/starship/commit/af43aeefba1cc12044f05a09a8b6f0ae309a556c time.rs 1-Fn
# https://github.com/swc-project/swc/commit/9ba68c68639916b48b79ad831e3cf69d7b0c8051 typescript.rs 6-Fn
# https://github.com/swc-project/swc/commit/716bfe05b298c750c08e56264485e48072539369 typescript.rs 1-Impl
# https://github.com/AppFlowy-IO/AppFlowy/commit/420b8ca05dcc27a50158bbddb08ec78b05cea0c4 grid.rs 19-Impl
# https://github.com/yewstack/yew/commit/c9deba05f13eac459f00198f878f272fc369516e mod.rs 0-Fn
# https://github.com/AppFlowy-IO/AppFlowy/commit/7cceafa432085689d64125182a748bbb4de4637d ast.rs 1-Fn
# https://github.com/nushell/nushell/commit/328f7e92a0d8411bc8832b321d0fd644c0ab7130 which_.rs 1-Fn
# https://github.com/meilisearch/meilisearch/commit/36c7fd0cf18a2aa78e3943bf95499b353977322d setting.rs 10-Fn
# https://github.com/xi-editor/xi-editor/commit/bed5b4341460d2330b9249f10e62d1a5b4dadf56 rpc.rs 2-Impl
# https://github.com/denoland/deno/commit/1cd95dd8b5046484ea79b1849e420d1c085d1e5b tty.rs 3-Fn
# https://github.com/tauri-apps/tauri/commit/c8d9726a0929a041d7cedde5dd0a6034c3869ae1 runner.rs 8-Fn
# https://github.com/nushell/nushell/commit/6514a30b5d33526465e72af21caba9c9371b5b41 md.rs 4-Fn
# https://github.com/AppFlowy-IO/AppFlowy/commit/cfb589dda1c0b312097e3188f65b09118e20043e controller.rs 0-Impl
# https://github.com/alacritty/alacritty/commit/217ad9ec285b4923de1790b0976c8c793039c994 mod.rs 15-Impl
# https://github.com/starship/starship/commit/56d475578ea508631275772127f49a6949fea6b0 git_status.rs 23-Fn
# https://github.com/AppFlowy-IO/AppFlowy/commit/cfb589dda1c0b312097e3188f65b09118e20043e controller.rs 6-Fn
# https://github.com/SergioBenitez/Rocket/commit/5d9035ddc1346c43ae1b1038500e548ef46d61d4 cookies.rs 5-Impl
# https://github.com/yewstack/yew/commit/e9de1652cf92b019447a912e99b9e45f0dbb176d vtag.rs 0-Impl
# https://github.com/AppFlowy-IO/AppFlowy/commit/3abd5b953e9cbde32ebdd11a3137cdf96f40ee96 workspace_deps.rs 1-Impl
# https://github.com/SergioBenitez/Rocket/commit/63a14525d86595a8033715e3bdcd2bf2581eecb1 flash-lazy-removes-issue-466.rs 1-Fn
# https://github.com/tauri-apps/tauri/commit/a1929c6dacccd00af4cdbcc4d29cfb98d8428f55 build.rs 0-Fn
# https://github.com/AppFlowy-IO/AppFlowy/commit/cfb589dda1c0b312097e3188f65b09118e20043e cache.rs 0-Impl
# https://github.com/xi-editor/xi-editor/commit/fcfa6514046af28a797d7146ef0bbbca8e762ddd main.rs 2-Fn
# https://github.com/AppFlowy-IO/AppFlowy/commit/152cb17701137ac461522581da9f336cd1803989 persistence.rs 2-Impl
# https://github.com/swc-project/swc/commit/6a97c7bef8a1f846bfe34678fd0714b8fdcb56a5 unsafes.rs 0-Impl
# https://github.com/yewstack/yew/commit/7e2542cbf83fb4ed16709200189eddd2e61cd0d0 main.rs 0-Fn

# %%
full_dbscan_clusters.sort(key=len, reverse=True)
ID = 0
for cluster in full_dbscan_clusters:
    ID += 1
    print(len(cluster), "ID:", ID)
    samples = cluster.sample(min(50, len(cluster)), random_state=RANDOM_STATE)
    common_set = set()
    for index1, row in samples.iterrows():
        print("https://github.com/", end="")
        print(DS.loc[index1, 'proj'], end="/commit/")
        print(DS.loc[index1, 'commit'], end=" ")
        print(DS.loc[index1, 'file'], end=" ")
        print(DS.loc[index1, 'scope'])        
        print(DS.loc[index1, 'desc'])        
        row = row[:len(row)-1]
        row = row[row != 0]
        nonTerminals = set(row.to_dict().keys())
        print(nonTerminals)
        print("------")
        if len(common_set) == 0:
            common_set = nonTerminals
        else:
            common_set = common_set & nonTerminals
    for item in sorted(list(common_set)):
        print(item)
    print("=======\n")
# Out:
# 168 ID: 1
# https://github.com/meilisearch/meilisearch/commit/dc9ca2ebc99406a9422bdcbb1460d422f5b8523f documents_deletion.rs 1-Fn
# &
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'mutability', 'ExprForLoop', 'Path', 'Expr'}
# ------
# https://github.com/xi-editor/xi-editor/commit/7cd12f4ef6fb94cc78c521a853bbca8821482454 event_context.rs 1-Impl
# mut-&
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'ExprClosure', 'Path', 'ItemImpl'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/bba8f8ae018401c461788c98f39a6d4370adfb62 workspace_sql.rs 1-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'mutability', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/starship/starship/commit/af43aeefba1cc12044f05a09a8b6f0ae309a556c time.rs 1-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'mutability', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/denoland/deno/commit/44511e4f330e2d7099a16ed836629fa73dde9831 ops.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'ExprStruct', 'Ident', 'ExprReference', 'mutability', 'Arm', 'ExprMatch', 'Some', 'Path', 'Expr', 'FieldValue'}
# ------
# https://github.com/starship/starship/commit/56d475578ea508631275772127f49a6949fea6b0 git_status.rs 23-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'ExprTry', 'Some', 'Path', 'Expr'}
# ------
# https://github.com/yewstack/yew/commit/7c187d3292d3188daddb5fa9f13dd2edf819aeb4 use_context_hook.rs 0-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'ExprMethodCall', 'ExprClosure', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/xi-editor/xi-editor/commit/7cd12f4ef6fb94cc78c521a853bbca8821482454 lib.rs 2-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'Some', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/tauri-apps/tauri/commit/3953662b82625a26fcbe8521b3907902206bda56 runner.rs 3-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path'}
# ------
# https://github.com/tauri-apps/tauri/commit/10314cd5cfe956fe5b3ae10acf551a92bdc366d3 manager.rs 1-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/SergioBenitez/Rocket/commit/78e2f8a3c9ac61096b5f895a529106953a2f7ce9 uri_parsing.rs 1-Impl
# mut-&
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/cfb589dda1c0b312097e3188f65b09118e20043e helper.rs 2-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'mutability', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/yewstack/yew/commit/c9deba05f13eac459f00198f878f272fc369516e builder.rs 0-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'mutability', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/63874010415354e92eeffb22770fe6d55653398a main.rs 1-Fn
# &
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'Arm', 'ExprMatch', 'ExprMethodCall', 'ExprTry', 'Some', 'Path'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/bba8f8ae018401c461788c98f39a6d4370adfb62 sql_impl.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'mutability', 'Some', 'Path'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/cfb589dda1c0b312097e3188f65b09118e20043e token.rs 1-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'mutability', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/rust-lang/rustlings/commit/1cd9328a5872f1d6a95b02824e1af33a423c047a main.rs 1-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Path', 'Expr'}
# ------
# https://github.com/rust-lang/rustlings/commit/1cd9328a5872f1d6a95b02824e1af33a423c047a verify.rs 4-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'Arm', 'ExprMatch', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/nushell/nushell/commit/76079d518354922724ebb775e886d879fb4f7fee ssv.rs 4-Fn
# &
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'ExprTry', 'Some', 'Path'}
# ------
# https://github.com/meilisearch/meilisearch/commit/a03d9d496e2cd85c22e74811b4103053e850cb65 search.rs 2-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprForLoop', 'ExprTry', 'Some', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/3b2b8c4512709b9908a113af83f30e4fa97b9c49 fixture.rs 3-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/6229b7f5b9eb92164cf4a6e60447f123a080b829 ffi_request.rs 0-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/tauri-apps/tauri/commit/24fa21c9b7e7bad21918c41efae807cc99376917 shell.rs 0-Impl
# &
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'ExprBinary', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/tokio-rs/tokio/commit/8198ef38814c45f9dc02fcbf826225b5cf32a6bb task_local.rs 0-Impl
# &
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Ident', 'Local', 'ExprReference', 'mutability', 'Some', 'Path', 'Expr', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/tokio-rs/tokio/commit/08c21e7bac0c0163d236943aaa3c5738e4b5bc2e poll_evented.rs 14-Impl
# &
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/cfb589dda1c0b312097e3188f65b09118e20043e queue.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'Arm', 'ExprMatch', 'Some', 'Path', 'Expr'}
# ------
# https://github.com/nushell/nushell/commit/d79a3130b83e119408ca9a167b4a473bdda9e468 format_filesize.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'Arm', 'ExprMatch', 'Some', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/denoland/deno/commit/9853c96cc4686a6cd1ffa1e9081c012b8df72ff7 test.rs 1-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'Expr'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/bba8f8ae018401c461788c98f39a6d4370adfb62 controller.rs 3-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path'}
# ------
# https://github.com/xi-editor/xi-editor/commit/7cd12f4ef6fb94cc78c521a853bbca8821482454 lib.rs 17-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Ident', 'Local', 'ExprReference', 'mutability', 'Some', 'Path', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/bba8f8ae018401c461788c98f39a6d4370adfb62 v1_impl.rs 0-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'ExprForLoop', 'Arm', 'ExprMatch', 'ExprTry', 'mutability', 'Some', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/xi-editor/xi-editor/commit/7cd12f4ef6fb94cc78c521a853bbca8821482454 edit_ops.rs 3-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprForLoop', 'Some', 'Path', 'Expr'}
# ------
# https://github.com/swc-project/swc/commit/920d9a76784b6e2ac9ccbfd826f2253410bf2be5 fixture.rs 0-Impl
# &
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/tauri-apps/tauri/commit/c7621aa019023c56d8bdaa2103a437c65ec899f3 global_shortcut.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'ExprMethodCall', 'ExprTry', 'Some', 'ExprClosure', 'Path'}
# ------
# https://github.com/swc-project/swc/commit/9608605772351a2406870e19ed8738adf2147374 mod.rs 1-Fn
# &-mut
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'mutability', 'Arm', 'ExprMatch', 'Path', 'Expr'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/318d7e645640e4fa75cd5bbc9292757867bf9da6 row_loader.rs 0-Fn
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'ExprMethodCall', 'ExprClosure', 'Path'}
# ------
# https://github.com/ogham/exa/commit/755876e9b624d022ef6bbc6143d273eeb4e2e26e git.rs 2-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'mutability', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/starship/starship/commit/af43aeefba1cc12044f05a09a8b6f0ae309a556c elixir.rs 1-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'Arm', 'ExprMatch', 'ExprMethodCall', 'ExprTry', 'Some', 'ExprClosure', 'Path', 'Expr'}
# ------
# https://github.com/starship/starship/commit/af43aeefba1cc12044f05a09a8b6f0ae309a556c status.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'mutability', 'Arm', 'ExprMatch', 'Some', 'Path'}
# ------
# https://github.com/starship/starship/commit/56d475578ea508631275772127f49a6949fea6b0 git_branch.rs 13-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'ExprTry', 'Some', 'Path', 'Expr'}
# ------
# https://github.com/swc-project/swc/commit/76e646804a025e2a451314013a437e79a6cd8ce2 mangle.rs 5-Fn
# mut-&
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'ExprMethodCall', 'ExprTry', 'Some', 'ExprClosure', 'Path', 'PatIdent', 'Expr'}
# ------
# https://github.com/nushell/nushell/commit/76079d518354922724ebb775e886d879fb4f7fee ics.rs 0-Impl
# mut-&
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path', 'PatIdent', 'Expr', 'ItemImpl'}
# ------
# https://github.com/alacritty/alacritty/commit/6e1b9d8b2502f5b47dc28eb5e0853e46ad8b4e84 mod.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'mutability', 'Path', 'Expr'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/b3ed254cafe681c466e19ac45c46b114a1e3055a manager.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path'}
# ------
# https://github.com/starship/starship/commit/f40f73dc8e26e6d8730344f4c6cbb47ee3d48342 golang.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'Arm', 'ExprMatch', 'ExprTry', 'Some', 'Path', 'Expr'}
# ------
# https://github.com/xi-editor/xi-editor/commit/7cd12f4ef6fb94cc78c521a853bbca8821482454 diff.rs 1-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'mutability', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/SergioBenitez/Rocket/commit/9671115796e42865eaebd020ac27542802027b02 rocket.rs 0-Impl
# &
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'ItemImpl'}
# ------
# https://github.com/tokio-rs/tokio/commit/8198ef38814c45f9dc02fcbf826225b5cf32a6bb orphan.rs 1-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'Arm', 'ExprMatch', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/yewstack/yew/commit/c9deba05f13eac459f00198f878f272fc369516e mod.rs 0-Fn
# &
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'mutability', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Path'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/2dd59305603dc150a7baf6fcf265c447e1bef818 text_type_option.rs 1-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# ExprPath
# ExprReference
# Ident
# Path
# PathSegment
# mutability
# =======
#
# 98 ID: 2
# https://github.com/AppFlowy-IO/AppFlowy/commit/013d8f753aa84f91dec2cfcba568886d17d10a91 module.rs 0-Fn
# clone
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'ExprMethodCall', 'Path', 'Expr'}
# ------
# https://github.com/ogham/exa/commit/cbd2f1fa37c2e0f33ecd27fb3c01edcb1182d37f dir.rs 0-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'ExprForLoop', 'ExprMethodCall', 'ExprMatch', 'Some', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/tauri-apps/tauri/commit/40ac52971eb350e839f41401043c5cde31fa8974 global_shortcut.rs 0-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'ExprBlock', 'Local', 'Arm', 'ExprMatch', 'ExprMethodCall', 'ExprTry', 'Some', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/3abd5b953e9cbde32ebdd11a3137cdf96f40ee96 module.rs 0-Fn
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'ExprMethodCall', 'Path', 'Expr'}
# ------
# https://github.com/nushell/nushell/commit/72838cc0837826777fa4921b32852fbb09b6a5e4 from_xml.rs 2-Fn
# clone
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'ExprMethodCall', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/denoland/deno/commit/4d18f558e4cfebc5b8d9d594401e3ce74fc3226b web_worker.rs 6-Impl
# clone
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprBlock', 'Local', 'clone', 'ExprMethodCall', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/6514a30b5d33526465e72af21caba9c9371b5b41 md.rs 4-Fn
# clone
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'ExprBlock', 'ExprForLoop', 'ExprMethodCall', 'Some', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/yewstack/yew/commit/e9de1652cf92b019447a912e99b9e45f0dbb176d vtag.rs 0-Impl
# clone
# {'ExprField', 'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Field', 'Ident', 'clone', 'ExprMethodCall', 'Some', 'Path', 'Expr', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/swc-project/swc/commit/eaeffabf74d73696bb45e106a92cbcd9fd34d8f3 spread.rs 2-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Ident', 'ExprBlock', 'Local', 'clone', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'Path', 'Expr', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/meilisearch/meilisearch/commit/4986adc186b9db00a2a4fd2dec6fbbcce2335e93 index.rs 3-Fn
# clone
# {'ExprField', 'ExprPath', 'PathSegment', 'ItemFn', 'ExprStruct', 'Field', 'Ident', 'Local', 'clone', 'ExprMethodCall', 'Some', 'Path', 'ExprIf', 'Expr', 'FieldValue'}
# ------
# https://github.com/nushell/nushell/commit/97eb8492a3a6cae82bc65198b898bbf51409dfb4 collect.rs 0-Impl
# clone
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'clone', 'ExprMethodCall', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/meilisearch/meilisearch/commit/f80ea24d2b581bd6c1a922992072f2f0873f8a77 search.rs 2-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'Local', 'ExprForLoop', 'ExprMethodCall', 'ExprTry', 'Some', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/db3ff529735bb923b2f9cc42012bc112ffe1f42b classified.rs 5-Impl
# clone
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'Local', 'clone', 'ExprMethodCall', 'ExprTry', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/6514a30b5d33526465e72af21caba9c9371b5b41 string.rs 1-Fn
# clone
# {'ExprPath', 'PathSegment', 'ItemFn', 'ExprStruct', 'Ident', 'clone', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Path', 'Expr', 'FieldValue'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/3abd5b953e9cbde32ebdd11a3137cdf96f40ee96 helper.rs 4-Fn
# clone
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'ExprStruct', 'Field', 'Ident', 'Local', 'clone', 'ExprMethodCall', 'Some', 'Path', 'FieldValue'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/3abd5b953e9cbde32ebdd11a3137cdf96f40ee96 file.rs 1-Fn
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'ExprMethodCall', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/tokio-rs/tokio/commit/0da23aad772afb22db8edf73ac0f034c5ada3bde watch.rs 4-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'ExprMethodCall', 'ExprClosure', 'Path', 'Attribute', 'Expr', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/eaeffabf74d73696bb45e106a92cbcd9fd34d8f3 destructuring.rs 7-Fn
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'ExprStruct', 'Ident', 'clone', 'ExprMethodCall', 'Path', 'ExprIf', 'Expr', 'FieldValue'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/739333c29c088c1b2c6c346629d4422bcc571dc8 mod.rs 0-Impl
# clone
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'Local', 'clone', 'ExprMethodCall', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/denoland/deno/commit/a43984c9cfcea852ca18e1c575f9acdb8f023a5a source_maps.rs 0-Fn
# clone
# {'ExprField', 'ExprPath', 'PathSegment', 'ItemFn', 'ExprStruct', 'Field', 'Ident', 'clone', 'ExprMethodCall', 'Some', 'Path', 'Expr', 'FieldValue'}
# ------
# https://github.com/firecracker-microvm/firecracker/commit/7d8e74475dc61fce56b8edf4c82f94dd82c7b4cf builder.rs 14-Fn
# clone
# {'ExprField', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'clone', 'ExprForLoop', 'ExprMethodCall', 'ExprTry', 'Path', 'Expr'}
# ------
# https://github.com/meilisearch/meilisearch/commit/07319713006587cef28ab9503efcba64756ca413 meilisearch.rs 0-Fn
# clone
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'Local', 'ExprForLoop', 'ExprMethodCall', 'Some', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/alacritty/alacritty/commit/4e1f4c8cd7180606156b71ad0222f60e4559f2b3 mod.rs 7-Impl
# clone
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'Local', 'clone', 'ExprMethodCall', 'ExprAssign', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/tauri-apps/tauri/commit/bef9f2845e14cf5b7955a39ba5cc262a96e548b8 lib.rs 0-Fn
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'ExprBlock', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Path', 'ExprIf', 'Attribute', 'Expr'}
# ------
# https://github.com/tokio-rs/tokio/commit/c5d37204dc7c4a3f1de2e413f151bd7d23e7e63d handle.rs 0-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Ident', 'clone', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/3abd5b953e9cbde32ebdd11a3137cdf96f40ee96 app_update.rs 1-Impl
# clone
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'Local', 'clone', 'Arm', 'ExprMatch', 'ExprMethodCall', 'ExprTry', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/3e03ebf8bb527d3237b309c3df3a24bc9ebf7314 fixture.rs 1-Fn
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'ExprBlock', 'Arm', 'ExprMatch', 'ExprMethodCall', 'ExprClosure', 'Path', 'Expr'}
# ------
# https://github.com/nushell/nushell/commit/8dc5c3493246de897e481034ea7d9ffa2e73e6cd context.rs 1-Impl
# clone
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Field', 'ExprBlock', 'Ident', 'clone', 'ExprMethodCall', 'Some', 'Path', 'Expr', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/tokio-rs/tokio/commit/9264b837d897dcdf974703a6739132b995e669bc sync_mutex_owned.rs 1-Fn
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'Local', 'ExprMethodCall', 'Some', 'Path'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/739333c29c088c1b2c6c346629d4422bcc571dc8 router.rs 0-Fn
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'ExprBlock', 'Local', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'Path', 'Expr'}
# ------
# https://github.com/tauri-apps/tauri/commit/8d2e4c63c7f660a1ff8e79d46f461ccfcf5bcc2e manager.rs 4-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'ExprBlock', 'Local', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/meilisearch/meilisearch/commit/85d0a914ac405520f4477ee901ca820fcae974e4 common.rs 0-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'Local', 'ExprMethodCall', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/yewstack/yew/commit/cb5a609e0897d3c79a07aa2f5c2b377a8e54c12a bcomp.rs 3-Impl
# clone
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'Local', 'ExprMethodCall', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/72838cc0837826777fa4921b32852fbb09b6a5e4 from_bson.rs 1-Fn
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'ExprBlock', 'Arm', 'ExprMatch', 'ExprMethodCall', 'ExprTry', 'Path', 'Expr'}
# ------
# https://github.com/meilisearch/meilisearch/commit/abbea5973207e38ae698e347033ebba6bedf4896 uuid_resolver.rs 3-Impl
# clone
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'Field', 'Local', 'clone', 'ExprMethodCall', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/bc1e1aa944e450c322512b55c187bdbc0fbeae56 empty.rs 1-Fn
# clone
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'ExprBlock', 'ExprForLoop', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/yewstack/yew/commit/2576372e267265418674e9613965ba13ec1429ea bcomp.rs 2-Impl
# clone
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'clone', 'TypePath', 'ExprMethodCall', 'Path', 'Type', 'Expr', 'ItemImpl'}
# ------
# https://github.com/yewstack/yew/commit/fa8a1d9f007b00c02a3e3edabbb6d87fad9dc58c main.rs 1-Fn
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'ExprMethodCall', 'Path'}
# ------
# https://github.com/denoland/deno/commit/7aba07cc7711adfa774afd8e77695f386127c4bc worker.rs 9-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'ExprBlock', 'ExprMethodCall', 'Some', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/meilisearch/meilisearch/commit/f77f38dfa09caf9b1345c9232c57bb8c37ac18d7 serializer.rs 0-Fn
# clone
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'Local', 'ExprMethodCall', 'ExprTry', 'Some', 'Path'}
# ------
# https://github.com/swc-project/swc/commit/8615d69ac385979bc7a0bf5a49be5d8e87d3a8ec umd.rs 0-Impl
# clone
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'clone', 'ExprForLoop', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/xi-editor/xi-editor/commit/add9e3e2f74c1324e85d1e2208f361b435b3fe2f lib.rs 4-Fn
# clone
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Path', 'Expr'}
# ------
# https://github.com/xi-editor/xi-editor/commit/53c5b9622492f52386c349fd8f9e83ecbbbd7c95 config.rs 8-Impl
# clone
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/72838cc0837826777fa4921b32852fbb09b6a5e4 command.rs 12-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'Local', 'ExprMethodCall', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/yewstack/yew/commit/2576372e267265418674e9613965ba13ec1429ea btext.rs 0-Impl
# clone
# {'ExprField', 'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'clone', 'TypePath', 'ExprMethodCall', 'Path', 'Type', 'Expr', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/cc5c4d38bb9d0945e41691a0d8a93a5f84fe257f from_value.rs 19-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/72838cc0837826777fa4921b32852fbb09b6a5e4 help_shell.rs 0-Impl
# clone
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'ExprBlock', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/72838cc0837826777fa4921b32852fbb09b6a5e4 lib.rs 2-Fn
# clone
# {'ExprField', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'clone', 'ExprMethodCall', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/3abd5b953e9cbde32ebdd11a3137cdf96f40ee96 helper.rs 5-Fn
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'clone', 'Local', 'ExprMethodCall', 'Some', 'Path'}
# ------
# https://github.com/xi-editor/xi-editor/commit/bed5b4341460d2330b9249f10e62d1a5b4dadf56 rpc.rs 1-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'clone', 'ExprBlock', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# ExprMethodCall
# ExprPath
# Ident
# Path
# PathSegment
# clone
# =======
#
# 97 ID: 3
# https://github.com/xi-editor/xi-editor/commit/e39dcbae4504d63113a561e1351a48196b05663b index_set.rs 0-Impl
# &-mut
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Field', 'Ident', 'ExprReference', 'mutability', 'Path', 'Expr', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/e2e47e8df071661a9a9e7318acc723a1b9d1e689 errors.rs 4-Impl
# &-mut
# {'ExprField', 'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/tauri-apps/tauri/commit/8fd1baf69b14bb81d7be9d31605ed7f02058b392 mod.rs 2-Fn
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/starship/starship/commit/2a650bfd140d561f955705cae124fb254ec549a1 nodejs.rs 0-Fn
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path', 'Expr'}
# ------
# https://github.com/nushell/nushell/commit/5fbea31d151572334008553a3ce43c64dea9e6c7 syntax_shape.rs 11-Impl
# mut-&
# {'ExprField', 'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'mutability', 'TypePath', 'Some', 'Path', 'Type', 'Expr', 'ItemImpl'}
# ------
# https://github.com/tauri-apps/tauri/commit/b92eee019c5d8d807ebfe4f7ad9c08baba536750 deb_bundle.rs 9-Fn
# &
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprForLoop', 'ExprMethodCall', 'ExprTry', 'Some', 'Path', 'Expr'}
# ------
# https://github.com/nushell/nushell/commit/e4226def162012e7fafc3f74242cdf290ce19113 syntax_shape.rs 10-Impl
# &-mut
# {'ExprField', 'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'mutability', 'TypePath', 'Some', 'Path', 'Type', 'Expr', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/834cd4f7b6866729b345fe68ce6386dc94b202d7 source_map.rs 5-Fn
# &
# {'ExprField', 'PathSegment', 'ExprReference', 'mutability', 'ExprMatch', 'ExprClosure', 'Expr', 'Field', 'Local', 'Arm', 'ExprMethodCall', 'Some', 'ExprPath', 'Ident', 'ExprBlock', 'ExprForLoop', 'Attribute', 'ExprCall', 'ItemFn', 'Path'}
# ------
# https://github.com/swc-project/swc/commit/4fb932dd0818c76feac01df7ea0c371626b62143 mod.rs 0-Fn
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'Expr'}
# ------
# https://github.com/starship/starship/commit/af43aeefba1cc12044f05a09a8b6f0ae309a556c ocaml.rs 1-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'Expr'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/cfb589dda1c0b312097e3188f65b09118e20043e ast.rs 0-Impl
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'Arm', 'ExprMatch', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/starship/starship/commit/2d4b183fce8c9de0d9548f7087786bc919cae7b4 configure.rs 2-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'Some', 'Path', 'ExprIf'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/cfb589dda1c0b312097e3188f65b09118e20043e deserialize.rs 0-Fn
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/9bb516786eeb247b5daeaf1cdb4577b98bf0a446 controller.rs 0-Impl
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path', 'ExprIf', 'ItemImpl'}
# ------
# https://github.com/xi-editor/xi-editor/commit/7cd12f4ef6fb94cc78c521a853bbca8821482454 editor.rs 0-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/cfb589dda1c0b312097e3188f65b09118e20043e serialize.rs 1-Fn
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'Some', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/denoland/deno/commit/c577c273a467123851be5ce3b0bba1095e6cd621 bindings.rs 4-Fn
# mut
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'Expr'}
# ------
# https://github.com/meilisearch/meilisearch/commit/85a1f126bfe82c62ddb6afcc4c879ea4b9914346 sum_of_typos.rs 0-Impl
# mut-&
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/48d61039d24aaef688bf0d573d6f6037366c5eec mod.rs 18-Impl
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/ac578b8491ee82f6c80852db55a220d757458441 command.rs 1-Fn
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'Arm', 'ExprMatch', 'ExprMethodCall', 'ExprTry', 'Some', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/nushell/nushell/commit/f70c6d5d485a1d533fee15a7d5af6275b2e1ee96 to_sqlite.rs 2-Fn
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprReference', 'mutability', 'Arm', 'ExprMatch', 'PatTupleStruct', 'Path', 'Expr'}
# ------
# https://github.com/starship/starship/commit/c4439531d35dfbed008a0dd519aa89bb67dcce24 print.rs 4-Fn
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path'}
# ------
# https://github.com/alacritty/alacritty/commit/5d173f6df3b20308eb318cef4b58147b2197d5f9 mod.rs 3-Impl
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Field', 'Ident', 'ExprReference', 'Local', 'mutability', 'ExprMethodCall', 'ExprAssign', 'Some', 'Path', 'Expr', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/tauri-apps/tauri/commit/c7621aa019023c56d8bdaa2103a437c65ec899f3 manager.rs 0-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'ExprMethodCall', 'ExprTry', 'Some', 'ExprClosure', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/tokio-rs/tokio/commit/8198ef38814c45f9dc02fcbf826225b5cf32a6bb harness.rs 1-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/cfb589dda1c0b312097e3188f65b09118e20043e deserialize.rs 1-Fn
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'Local', 'ExprReference', 'mutability', 'Arm', 'ExprMatch', 'ExprTry', 'Some', 'Path', 'Expr'}
# ------
# https://github.com/starship/starship/commit/ecc87543350d7addba9fc2539986808ae07106dc package.rs 0-Fn
# &
# {'ExprField', 'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprReference', 'mutability', 'ExprMatch', 'Path', 'Expr'}
# ------
# https://github.com/ogham/exa/commit/755876e9b624d022ef6bbc6143d273eeb4e2e26e grid.rs 0-Impl
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'ExprForLoop', 'ExprMethodCall', 'Some', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/2e29d7828164493ec6e8e3c043325ebcd2d935e1 lib.rs 2-Impl
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/ff47e2539ed08272740bb1c09d27c2b87a78ae0d config.rs 19-Impl
# mut-&
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'ItemImpl'}
# ------
# https://github.com/tauri-apps/tauri/commit/8fd1baf69b14bb81d7be9d31605ed7f02058b392 mod.rs 3-Fn
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'ExprMethodCall', 'ExprMatch', 'ExprClosure', 'Path', 'Expr'}
# ------
# https://github.com/starship/starship/commit/af43aeefba1cc12044f05a09a8b6f0ae309a556c elm.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path', 'Expr'}
# ------
# https://github.com/swc-project/swc/commit/6a97c7bef8a1f846bfe34678fd0714b8fdcb56a5 strings.rs 0-Impl
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/74dcd91cc35e1b07dc8643c6091eeb5fa3f5aa24 expand.rs 0-Fn
# &
# {'ExprField', 'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprReference', 'mutability', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/starship/starship/commit/c4439531d35dfbed008a0dd519aa89bb67dcce24 print.rs 1-Fn
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path'}
# ------
# https://github.com/nushell/nushell/commit/f70c6d5d485a1d533fee15a7d5af6275b2e1ee96 dict.rs 6-Impl
# mut-&
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'mutability', 'Arm', 'ExprMatch', 'PatTupleStruct', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/meilisearch/meilisearch/commit/b71bbcffaad8245f562bf4eb098e7c038759fa7e index.rs 5-Fn
# &-mut
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'ExprTry', 'Some', 'Path'}
# ------
# https://github.com/swc-project/swc/commit/6a97c7bef8a1f846bfe34678fd0714b8fdcb56a5 loops.rs 0-Impl
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'mutability', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/alacritty/alacritty/commit/2920cbe7103f03a45080bfb7610bd7f481f36361 main.rs 2-Fn
# &-mut
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path'}
# ------
# https://github.com/starship/starship/commit/36ae36282a9436c3944807c9f64356c63d298c38 directory.rs 0-Fn
# &
# {'ExprField', 'PathSegment', 'ExprReference', 'mutability', 'ExprMatch', 'ExprClosure', 'Expr', 'Field', 'Local', 'Arm', 'ExprMethodCall', 'ExprTry', 'Some', 'ExprIf', 'ExprPath', 'Ident', 'ExprBlock', 'ExprCall', 'ItemFn', 'Path'}
# ------
# https://github.com/swc-project/swc/commit/6a97c7bef8a1f846bfe34678fd0714b8fdcb56a5 bools.rs 0-Impl
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'Local', 'ExprReference', 'mutability', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/e252265a3f21a4c0dcef2e9c13aa7365f683b235 mod.rs 0-Fn
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'Expr'}
# ------
# https://github.com/swc-project/swc/commit/9dec9236f7b3c95c803571404d7abae71e173936 mod.rs 0-Fn
# &
# {'ExprField', 'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'Expr'}
# ------
# https://github.com/meilisearch/meilisearch/commit/5465e401bbb7e2cd82fe7acf26eeb96d499d6b9d bucket_sort.rs 2-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'ExprTry', 'Some', 'Path'}
# ------
# https://github.com/ogham/exa/commit/002080cde8d2f727c5b1e12aff91c268922f59eb table.rs 0-Impl
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Field', 'Ident', 'ExprReference', 'mutability', 'Path', 'Expr', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/yewstack/yew/commit/f5b921984ab8cc9b745cfe5a669a812f6d75e261 mod.rs 1-Impl
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'Local', 'ExprReference', 'mutability', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/denoland/deno/commit/dcd05d4cb9780b7ab6753de5267bc59d834d8022 ops_unix.rs 2-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'ExprTry', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/yewstack/yew/commit/86a7b255e70aa8f4b74091916f94ff7beeb07b24 vcomp.rs 6-Impl
# mut-&
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'mutability', 'ExprMethodCall', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/xi-editor/xi-editor/commit/d674801625ced00c94ae81545af41018b0ac1d5a spans.rs 1-Impl
# mut-&
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'mutability', 'ExprForLoop', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/72838cc0837826777fa4921b32852fbb09b6a5e4 tokens_iterator.rs 2-Impl
# mut-&
# {'ExprField', 'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'mutability', 'Path', 'Expr', 'ItemImpl'}
# ------
# ExprPath
# ExprReference
# Ident
# Path
# PathSegment
# mutability
# =======
#
# 55 ID: 4
# https://github.com/meilisearch/meilisearch/commit/a067a1b16b5a661652a454ef2b0245d786619014 setting.rs 16-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path', 'PatIdent', 'Expr'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/3abd5b953e9cbde32ebdd11a3137cdf96f40ee96 lib.rs 0-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'ExprMethodCall', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/starship/starship/commit/5901ec026f09de570ca5d198429e9283ae74b7b5 context.rs 0-Impl
# &
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Ident', 'ExprReference', 'Path', 'Expr', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/nushell/nushell/commit/cc3653cfd981672a95bb3942dbdc718290bc5453 basename.rs 0-Impl
# &
# {'ExprField', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'Expr', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/7e184b58b2f9bc4249e97b07fed9ea766238c372 nu_plugin_extra_from_bson.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'Path'}
# ------
# https://github.com/nushell/nushell/commit/1b2fdf7c1eb6666c74ef5b7700f87de6219a833e filesystem_shell.rs 2-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'Some', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/meilisearch/meilisearch/commit/a5b0e468eef3a12dcf6d95da11c1443523206fce documents_deletion.rs 1-Fn
# &
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'ExprForLoop', 'ExprMethodCall', 'Some', 'Path', 'PatIdent', 'Expr'}
# ------
# https://github.com/swc-project/swc/commit/9ba68c68639916b48b79ad831e3cf69d7b0c8051 lib.rs 3-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'ExprMethodCall', 'ExprTry', 'Some', 'ExprClosure', 'Path', 'Expr'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/1faf959e1ea0be9b8e2cad0f653054818accf2db preserve_block_format.rs 0-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/starship/starship/commit/e09b821c42c02035717326820083f6725ed1a83e main.rs 1-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'Arm', 'ExprMatch', 'Path', 'Expr'}
# ------
# https://github.com/SergioBenitez/Rocket/commit/b8ba7b855f28be1f17bd65b35dd8597d368369ff tests.rs 3-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'ExprStruct', 'Ident', 'Local', 'ExprReference', 'ExprMethodCall', 'ExprAssign', 'Some', 'Path', 'PatIdent', 'FieldValue'}
# ------
# https://github.com/swc-project/swc/commit/306cf989db7292387cb7369242ef0025233d775e debug.rs 0-Fn
# &
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'ExprStruct', 'ExprReference', 'ExprMethodCall', 'Path'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/dfcb5059bf187e2dec1de83ab1f989cd1f713195 view_controller.rs 0-Impl
# &
# {'ExprField', 'ExprCall', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/57d1aaf80f4e9b21121318759cde4f864692bc46 lib.rs 2-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprReference', 'ExprMethodCall', 'ExprTry', 'Path', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/910869b79d32f8150d7e7f3323802cf20e3dd72a ls.rs 0-Fn
# &
# {'ExprField', 'ItemFn', 'Ident', 'Field', 'Local', 'ExprReference', 'ExprMethodCall', 'Some'}
# ------
# https://github.com/alacritty/alacritty/commit/0ca5c7a6956d2af95f798b858e646e5ec8e63403 mod.rs 3-Impl
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'ExprMethodCall', 'Path', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/e46a842e99bba7ff63957ddd199c1eb970440371 babelify.rs 2-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path', 'Expr'}
# ------
# https://github.com/swc-project/swc/commit/6a97c7bef8a1f846bfe34678fd0714b8fdcb56a5 optimize.rs 0-Impl
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'ExprMethodCall', 'ExprAssign', 'ExprClosure', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/6a97c7bef8a1f846bfe34678fd0714b8fdcb56a5 load.rs 3-Impl
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/9ba68c68639916b48b79ad831e3cf69d7b0c8051 fixture.rs 0-Fn
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'ExprForLoop', 'ExprMethodCall', 'Some', 'ExprClosure', 'Path', 'Expr'}
# ------
# https://github.com/meilisearch/meilisearch/commit/2eb6f81c589dae67fdcaa0773a11617d1046da44 setting.rs 6-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'ExprMethodCall', 'ExprTry', 'Some', 'Path', 'PatIdent', 'Expr'}
# ------
# https://github.com/starship/starship/commit/1c9758f08b9bcf72c5d197e90bc8a67d271e21d5 kotlin.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'Path', 'PatIdent', 'Expr'}
# ------
# https://github.com/nushell/nushell/commit/f70c6d5d485a1d533fee15a7d5af6275b2e1ee96 utils.rs 0-Fn
# &
# {'ExprField', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'Local', 'ExprReference', 'Arm', 'ExprMatch', 'Some', 'PatTupleStruct', 'Path'}
# ------
# https://github.com/nushell/nushell/commit/7e184b58b2f9bc4249e97b07fed9ea766238c372 main.rs 0-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'Path', 'Expr'}
# ------
# https://github.com/tokio-rs/tokio/commit/9c037044c4b837a7803be34c6d1a5e23d16011de sender.rs 2-Impl
# &
# {'ExprField', 'ImplItemMethod', 'Ident', 'Field', 'Local', 'ExprReference', 'ExprMethodCall', 'Some', 'ItemImpl'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/1faf959e1ea0be9b8e2cad0f653054818accf2db reset_format_on_new_line.rs 0-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'ExprMethodCall', 'Some', 'Path', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/starship/starship/commit/9b52475e541f751e8c650587cd8c1615fe00b1d0 mod.rs 1-Fn
# &
# {'ExprCall', 'ItemFn', 'Ident', 'ExprReference', 'Arm', 'ExprMatch', 'ExprMethodCall', 'ExprTry'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/ab2a997a77c3f03ccad7c71df0a8638a730c4776 revision.rs 2-Impl
# &
# {'ExprField', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'Expr', 'ItemImpl'}
# ------
# https://github.com/tauri-apps/tauri/commit/ec2b9092edb292f96aa9d6108cd5adf584252dc7 wix.rs 7-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'ExprMethodCall', 'Some', 'Path'}
# ------
# https://github.com/tauri-apps/tauri/commit/c7621aa019023c56d8bdaa2103a437c65ec899f3 core.rs 9-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'Local', 'ExprReference', 'ExprMethodCall', 'ExprTry', 'Some', 'Path'}
# ------
# https://github.com/swc-project/swc/commit/f44e25c3afba2470e8013b757a6bacf30614b1f9 iife.rs 1-Impl
# &
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'Local', 'ExprReference', 'ExprAssign', 'Some', 'Path', 'ItemImpl'}
# ------
# ...
# ------
# https://github.com/nushell/nushell/commit/f702aae72fd4d218ead1bd639d99b999198fef3b cal.rs 2-Fn
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'TypeReference', 'ExprReference', 'mutability', 'ExprForLoop', 'TypePath', 'Path', 'PatIdent', 'Expr'}
# ------
# ExprPath
# ExprReference
# Ident
# ItemFn
# Path
# PathSegment
# TypePath
# TypeReference
# mutability
# =======
#
# 6 ID: 40
# https://github.com/tokio-rs/tokio/commit/646fbae76535e397ef79dbcaacb945d4c829f666 thread.rs 1-Impl
# mut
# {'Mut', 'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'mutability', 'ExprMethodCall', 'Some', 'Path', 'Generics', 'ItemImpl'}
# ------
# https://github.com/tokio-rs/tokio/commit/3e643c7b81736a4c2b11387a6f71aba99450270b delay.rs 0-Impl
# mut
# {'Mut', 'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'mutability', 'ExprMethodCall', 'Some', 'Path', 'Attribute', 'Generics', 'ItemImpl'}
# ------
# https://github.com/tokio-rs/tokio/commit/646fbae76535e397ef79dbcaacb945d4c829f666 test_delay.rs 12-Fn
# mut
# {'Mut', 'ImplItemMethod', 'ItemFn', 'Ident', 'mutability', 'Some', 'Generics', 'ItemImpl'}
# ------
# https://github.com/tokio-rs/tokio/commit/5d0a81fb9182af4bacaf8be139f304e22bc2aade registration.rs 1-Impl
# mut
# {'Mut', 'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'mutability', 'ExprMethodCall', 'Some', 'Path', 'Generics', 'ItemImpl'}
# ------
# https://github.com/yewstack/yew/commit/5629f37b575c0c0468ad867975a09d07381710db reader.rs 3-Impl
# mut
# {'Mut', 'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'mutability', 'ExprMethodCall', 'Some', 'Path', 'Generics', 'ItemImpl'}
# ------
# https://github.com/tokio-rs/tokio/commit/646fbae76535e397ef79dbcaacb945d4c829f666 mod.rs 1-Impl
# mut
# {'Mut', 'ImplItemMethod', 'Ident', 'mutability', 'Some', 'Generics', 'ItemImpl'}
# ------
# Generics
# Ident
# ImplItemMethod
# ItemImpl
# Mut
# Some
# mutability
# =======
#
# 6 ID: 41
# https://github.com/yewstack/yew/commit/dfc4968203560f247b9716da2a0df38f7fcfd91d agent.rs 23-Impl
# clone-mut
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Ident', 'TypeReference', 'clone', 'mutability', 'TypePath', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/nushell/nushell/commit/8a29c9e6ab85c9d3844c31f2eae788e07393fca6 base.rs 5-Impl
# clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'TypeReference', 'clone', 'mutability', 'TypePath', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/e4226def162012e7fafc3f74242cdf290ce19113 shape.rs 10-Impl
# clone-mut
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'TypeReference', 'clone', 'mutability', 'TypePath', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/e4226def162012e7fafc3f74242cdf290ce19113 shape.rs 10-Impl
# mut-clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'TypeReference', 'clone', 'mutability', 'TypePath', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/yewstack/yew/commit/dfc4968203560f247b9716da2a0df38f7fcfd91d agent.rs 23-Impl
# mut-clone
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Ident', 'TypeReference', 'clone', 'mutability', 'TypePath', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/nushell/nushell/commit/f70c6d5d485a1d533fee15a7d5af6275b2e1ee96 parser.rs 4-Impl
# mut-clone
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'TypeReference', 'clone', 'mutability', 'TypePath', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# Expr
# ExprMethodCall
# ExprPath
# Ident
# ImplItemMethod
# ItemImpl
# Path
# PathSegment
# TypePath
# TypeReference
# clone
# mutability
# =======
#
# 6 ID: 42
# https://github.com/ogham/exa/commit/649744dc825b8e21c1b86bd3b11c122cf7b8d3ba filter.rs 1-Impl
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/denoland/deno/commit/63b8089bda8c88413bfad24aef415abc09e8d5c2 lint.rs 0-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'Local', 'ExprReference', 'Some', 'Path', 'ItemImpl'}
# ------
# https://github.com/tokio-rs/tokio/commit/27bfe52bba06283df3e9481b89a903390ee70369 batch_semaphore.rs 1-Impl
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'ExprMethodCall', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/e4226def162012e7fafc3f74242cdf290ce19113 generic.rs 0-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprBlock', 'ExprReference', 'Local', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/swc-project/swc/commit/cdf4a09e6594d5cf5b9151ab129072451b8476b7 mod.rs 3-Impl
# &
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'Field', 'Ident', 'ExprReference', 'Path', 'Expr', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/f70c6d5d485a1d533fee15a7d5af6275b2e1ee96 base.rs 3-Impl
# &
# {'ImplItemMethod', 'Ident', 'ExprBlock', 'ExprReference', 'ExprForLoop', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Expr', 'ItemImpl'}
# ------
# ExprReference
# Ident
# ImplItemMethod
# ItemImpl
# =======
#
# 5 ID: 43
# https://github.com/alacritty/alacritty/commit/d5c66ceeacb30a3ba97591bd8ae7eb4d11c7abf5 logging.rs 1-Impl
# &
# {'ExprPath', 'ExprCall', 'PathSegment', 'ImplItemMethod', 'ExprBinary', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'ExprUnary', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/alacritty/alacritty/commit/3a54ce899e48de45dc90de2aaa742f06b003dab4 mod.rs 15-Impl
# &-mut
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'ExprUnary', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/bba8f8ae018401c461788c98f39a6d4370adfb62 controller.rs 2-Impl
# &
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'ExprUnary', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# https://github.com/tauri-apps/tauri/commit/675d171eedacc1253f986fe7bdd8a7179d8b10b1 lib.rs 2-Fn
# &
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'ExprReference', 'mutability', 'ExprForLoop', 'ExprMethodCall', 'Path', 'ExprUnary', 'ExprIf', 'Expr'}
# ------
# https://github.com/AppFlowy-IO/AppFlowy/commit/cfb589dda1c0b312097e3188f65b09118e20043e controller.rs 3-Impl
# &
# {'ExprPath', 'PathSegment', 'ImplItemMethod', 'Ident', 'ExprReference', 'mutability', 'ExprMethodCall', 'Path', 'ExprUnary', 'ExprIf', 'Expr', 'ItemImpl'}
# ------
# Expr
# ExprIf
# ExprMethodCall
# ExprPath
# ExprReference
# ExprUnary
# Ident
# Path
# PathSegment
# mutability
# =======
#
# 5 ID: 44
# https://github.com/rustdesk/rustdesk/commit/efa6b5972da1b4d5105a8f8a10144415655e1963 common.rs 3-Fn
# as_ref
# {'ExprField', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'Local', 'ExprMethodCall', 'Some', 'as_ref', 'Path', 'ExprIf', 'Expr'}
# ------
# https://github.com/rustdesk/rustdesk/commit/efa6b5972da1b4d5105a8f8a10144415655e1963 connection.rs 0-Impl
# as_ref
# {'ExprField', 'ExprPath', 'PathSegment', 'ImplItemMethod', 'ExprStruct', 'Field', 'ExprBlock', 'Ident', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'as_ref', 'Path', 'ExprIf', 'Expr', 'ItemImpl', 'FieldValue'}
# ------
# https://github.com/nushell/nushell/commit/e06df124ca8077b53d8b2e03c71ac7df00f8fb90 from_sqlite.rs 1-Fn
# as_ref
# {'ExprPath', 'PathSegment', 'ItemFn', 'Ident', 'ExprForLoop', 'ExprMethodCall', 'as_ref', 'Path', 'Expr'}
# ------
# https://github.com/tauri-apps/tauri/commit/e511d3991041a974273a2674a9bf60230b7519ee updater.rs 3-Fn
# as_ref
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'Field', 'Ident', 'ExprBlock', 'Arm', 'ExprMatch', 'ExprMethodCall', 'as_ref', 'Path', 'Expr'}
# ------
# https://github.com/rustdesk/rustdesk/commit/efa6b5972da1b4d5105a8f8a10144415655e1963 clipboard_file.rs 1-Fn
# as_ref
# {'ExprField', 'ExprCall', 'ExprPath', 'PathSegment', 'ItemFn', 'ExprStruct', 'Field', 'ExprBlock', 'Ident', 'Arm', 'ExprMatch', 'ExprMethodCall', 'as_ref', 'Path', 'Expr', 'FieldValue'}
# ------
# Expr
# ExprMethodCall
# ExprPath
# Ident
# Path
# PathSegment
# as_ref
# =======
#
# 5 ID: 45
# https://github.com/nushell/nushell/commit/f46962d236fa42ce61002f45b46941e5d7263c21 mod.rs 25-Fn
# &
# {'LitStr', 'ItemFn', 'Lit', 'Ident', 'Local', 'ExprReference', 'ExprArray', 'Some', 'ExprLit'}
# ------
# https://github.com/nushell/nushell/commit/c3efb12733e40de5bb03702865aa91672a10d9fd mod.rs 19-Fn
# &
# {'LitStr', 'ItemFn', 'Lit', 'Ident', 'Local', 'ExprReference', 'ExprArray', 'Some', 'ExprLit'}
# ------
# https://github.com/rust-lang/rustlings/commit/71a06044e6a96ff756dc31d7b0ed665ae4badb57 exercise.rs 3-Impl
# &
# {'LitStr', 'ImplItemMethod', 'Lit', 'ExprBlock', 'ExprReference', 'ExprArray', 'Local', 'Arm', 'ExprMatch', 'ExprMethodCall', 'Some', 'ExprLit', 'Expr', 'ItemImpl'}
# ------
# https://github.com/starship/starship/commit/89fc93d1f907348dc2730469360aebdb5d689aec cmake.rs 0-Fn
# &
# {'LitStr', 'ItemFn', 'Lit', 'Local', 'ExprReference', 'ExprArray', 'ExprMethodCall', 'Some', 'ExprLit'}
# ------
# https://github.com/sharkdp/fd/commit/4d7e34ad591913a9f2eb453ba529b3f125887f11 tests.rs 70-Fn
# &
# {'LitStr', 'ItemFn', 'Lit', 'Ident', 'ExprReference', 'ExprArray', 'ExprMethodCall', 'ExprLit'}
# ------
# ExprArray
# ExprLit
# ExprReference
# Lit
# LitStr
# =======
#
# 5 ID: 46
# https://github.com/SergioBenitez/Rocket/commit/9b955747e46d671983d72caebf03791b64ddc5a2 rocket.rs 1-Macro
# clone
# {'Macro', 'ItemMacro', 'Ident', 'clone'}
# ------
# https://github.com/swc-project/swc/commit/4c6c4bc59594f30654c5bcdcf7d4b4aab84be023 tests.rs 7-Macro
# clone
# {'Macro', 'ItemMacro', 'Ident', 'clone'}
# ------
# https://github.com/yewstack/yew/commit/4a14d0f0a4df42616d94dfe600b9096dfe8b594a post.rs 1-Impl
# clone
# {'Macro', 'ImplItemMethod', 'Ident', 'clone', 'ItemMacro', 'ItemImpl'}
# ------
# https://github.com/yewstack/yew/commit/7e2542cbf83fb4ed16709200189eddd2e61cd0d0 post.rs 1-Impl
# clone
# {'Macro', 'ImplItemMethod', 'Ident', 'clone', 'ItemMacro', 'ItemImpl'}
# ------
# https://github.com/SergioBenitez/Rocket/commit/5d9035ddc1346c43ae1b1038500e548ef46d61d4 client.rs 1-Macro
# clone
# {'Macro', 'ItemMacro', 'Ident', 'clone'}
# ------
# Ident
# ItemMacro
# Macro
# clone
# =======
#
# 5 ID: 47
# https://github.com/tokio-rs/tokio/commit/8546ff826db8dba1e39b4119ad909fb6cab2492a pool.rs nan
# mut-'
# {'Mut', 'PathSegment', 'Lifetime', 'mutability', 'ExprLit', 'Expr', 'LitStr', 'ExprMethodCall', 'Some', 'Generics', 'ExprPath', 'ImplItemMethod', 'Ident', 'by_ref', 'PatIdent', 'AngleBracketedGenericArguments', 'Lit', 'TypeReference', 'TypePath', 'Path', 'Type', 'ItemImpl'}
# ------
# https://github.com/SergioBenitez/Rocket/commit/2893ce754d6535e0a752586e60d7e292343016c0 uri.rs nan
# '-mut
# {'Mut', 'PathSegment', 'Lifetime', 'mutability', 'ExprLit', 'Expr', 'LitStr', 'ExprMethodCall', 'Some', 'Generics', 'ExprPath', 'ImplItemMethod', 'Ident', 'by_ref', 'PatIdent', 'AngleBracketedGenericArguments', 'Lit', 'TypeReference', 'TypePath', 'Path', 'Type', 'ItemImpl'}
# ------
# https://github.com/yewstack/yew/commit/0b599335471d9c81293d39c406baf31fecc25d41 interval.rs nan
# mut-'
# {'Mut', 'PathSegment', 'Lifetime', 'mutability', 'ExprLit', 'Expr', 'LitStr', 'ExprMethodCall', 'Some', 'Generics', 'ExprPath', 'ImplItemMethod', 'Ident', 'by_ref', 'PatIdent', 'AngleBracketedGenericArguments', 'Lit', 'TypeReference', 'TypePath', 'Path', 'Type', 'ItemImpl'}
# ------
# https://github.com/yewstack/yew/commit/5fc4387dc58b7f87c9a71ee734bf04d307fb7226 keyboard.rs nan
# mut-'
# {'Mut', 'PathSegment', 'Lifetime', 'mutability', 'ExprLit', 'Expr', 'LitStr', 'ExprMethodCall', 'Some', 'Generics', 'ExprPath', 'ImplItemMethod', 'Ident', 'by_ref', 'PatIdent', 'AngleBracketedGenericArguments', 'Lit', 'TypeReference', 'TypePath', 'Path', 'Type', 'ItemImpl'}
# ------
# https://github.com/SergioBenitez/Rocket/commit/2893ce754d6535e0a752586e60d7e292343016c0 uri.rs nan
# mut-'
# {'Mut', 'PathSegment', 'Lifetime', 'mutability', 'ExprLit', 'Expr', 'LitStr', 'ExprMethodCall', 'Some', 'Generics', 'ExprPath', 'ImplItemMethod', 'Ident', 'by_ref', 'PatIdent', 'AngleBracketedGenericArguments', 'Lit', 'TypeReference', 'TypePath', 'Path', 'Type', 'ItemImpl'}
# ------
# AngleBracketedGenericArguments
# Expr
# ExprLit
# ExprMethodCall
# ExprPath
# Generics
# Ident
# ImplItemMethod
# ItemImpl
# Lifetime
# Lit
# LitStr
# Mut
# PatIdent
# Path
# PathSegment
# Some
# Type
# TypePath
# TypeReference
# by_ref
# mutability
# =======
#
# 5 ID: 48
# https://github.com/denoland/deno/commit/eb56186e4499c7584d2cfffdca4fde7ad3da16ee de.rs 2-Fn
# mut
# {'Mut', 'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'TypeReference', 'Local', 'by_ref', 'mutability', 'TypePath', 'Some', 'Path', 'PatIdent'}
# ------
# https://github.com/denoland/deno/commit/fec1b2a5a4324a7eecdfbb2471931f3b6b0139c5 de.rs 2-Fn
# mut
# {'Mut', 'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'TypeReference', 'Local', 'by_ref', 'mutability', 'TypePath', 'Some', 'Path', 'PatIdent'}
# ------
# https://github.com/tokio-rs/tokio/commit/003b4d8074e501f0185d0d38050219ec7b491bc3 lib.rs 22-Impl
# mut
# {'Mut', 'PathSegment', 'ImplItemMethod', 'Ident', 'TypeReference', 'by_ref', 'mutability', 'TypePath', 'Some', 'Path', 'PatIdent', 'ItemImpl'}
# ------
# https://github.com/firecracker-microvm/firecracker/commit/4ffc8a2c0c5cc7d673686e471bc6e096f6f9c86b persist.rs 7-Fn
# mut
# {'Mut', 'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'TypeReference', 'by_ref', 'mutability', 'TypePath', 'ExprMethodCall', 'Some', 'Path', 'PatIdent', 'Expr'}
# ------
# https://github.com/denoland/deno/commit/72eb6e1d7cfec721e33ac08943c0f97dce93fc23 de.rs 2-Fn
# mut
# {'Mut', 'ExprPath', 'ExprCall', 'PathSegment', 'ItemFn', 'Ident', 'TypeReference', 'Local', 'by_ref', 'mutability', 'TypePath', 'Some', 'Path', 'PatIdent'}
# ------
# Ident
# Mut
# PatIdent
# Path
# PathSegment
# Some
# TypePath
# TypeReference
# by_ref
# mutability
# =======
#
# 5 ID: 49
# https://github.com/ogham/exa/commit/550f2d29c2c4e7e1326df4cdcccb7d47d2e81cd5 error.rs nan
# '-mut
# {'Mut', 'PathSegment', 'Lifetime', 'Expr', 'Some', 'Generics', 'ImplItemMethod', 'Ident', 'by_ref', 'ExprMacro', 'Path', 'PatIdent', 'AngleBracketedGenericArguments', 'Macro', 'TypeReference', 'TypePath', 'mutability', 'Type', 'ItemImpl'}
# ------
# https://github.com/tokio-rs/tokio/commit/a7833e300780546c091e606bb2e077542f2e2e4e error.rs nan
# '-mut
# {'Mut', 'PathSegment', 'Lifetime', 'Expr', 'Some', 'Generics', 'ImplItemMethod', 'Ident', 'by_ref', 'ExprMacro', 'Path', 'PatIdent', 'AngleBracketedGenericArguments', 'Macro', 'TypeReference', 'TypePath', 'mutability', 'Type', 'ItemImpl'}
# ------
# https://github.com/tokio-rs/tokio/commit/a7833e300780546c091e606bb2e077542f2e2e4e error.rs nan
# mut-'
# {'Mut', 'PathSegment', 'Lifetime', 'Expr', 'Some', 'Generics', 'ImplItemMethod', 'Ident', 'by_ref', 'ExprMacro', 'Path', 'PatIdent', 'AngleBracketedGenericArguments', 'Macro', 'TypeReference', 'TypePath', 'mutability', 'Type', 'ItemImpl'}
# ------
# https://github.com/nushell/nushell/commit/5fbea31d151572334008553a3ce43c64dea9e6c7 binary.rs nan
# mut-'
# {'Mut', 'PathSegment', 'Lifetime', 'Expr', 'Some', 'Generics', 'ImplItemMethod', 'Ident', 'by_ref', 'ExprMacro', 'Path', 'PatIdent', 'AngleBracketedGenericArguments', 'Macro', 'TypeReference', 'TypePath', 'mutability', 'Type', 'ItemImpl'}
# ------
# https://github.com/alacritty/alacritty/commit/3bd5ac221ab3b122962063edd1f4c10f9f2d117f index.rs nan
# '-mut
# {'Mut', 'PathSegment', 'Lifetime', 'Expr', 'Some', 'Generics', 'ImplItemMethod', 'Ident', 'by_ref', 'ExprMacro', 'Path', 'PatIdent', 'AngleBracketedGenericArguments', 'Macro', 'TypeReference', 'TypePath', 'mutability', 'Type', 'ItemImpl'}
# ------
# AngleBracketedGenericArguments
# Expr
# ExprMacro
# Generics
# Ident
# ImplItemMethod
# ItemImpl
# Lifetime
# Macro
# Mut
# PatIdent
# Path
# PathSegment
# Some
# Type
# TypePath
# TypeReference
# by_ref
# mutability
# =======
